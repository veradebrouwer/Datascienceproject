# %%
# !pip3 install snscrape
# Out:
# Requirement already satisfied: snscrape in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (0.3.4)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from snscrape) (4.10.0)
# Requirement already satisfied: lxml in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from snscrape) (4.6.4)
# Requirement already satisfied: requests[socks] in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from snscrape) (2.26.0)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from beautifulsoup4->snscrape) (2.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests[socks]->snscrape) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests[socks]->snscrape) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests[socks]->snscrape) (2018.8.24)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests[socks]->snscrape) (3.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests[socks]->snscrape) (1.7.1)
# WARNING: You are using pip version 20.3.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.7/bin/python3.7 -m pip install --upgrade pip' command.

# %%
import sys 
sys.path.insert(0, r"/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages")

import snscrape.modules.twitter as sntwitter
import pandas as pd
import numpy as np

# %%
from platform import python_version

print(python_version())
# Out:
# 3.6.8

# %%
# importing libraries and packages


# Creating list to append tweet data 
tweets_list1 = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#'+'from:SaskiaBelleman').get_items()): #declare a username 
    if i>50:
        break
    tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.username]) #declare the attributes to be returned
    
tweets_df1 = pd.DataFrame(tweets_list1, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])
tweets_df1
# Out:
#                     Datetime             Tweet Id  \
# 0  2021-11-19 08:25:56+00:00  1461611687673487363
# 1  2021-11-19 08:21:47+00:00  1461610641878396933
# 2  2021-11-19 08:20:54+00:00  1461610420389781508
# 3  2021-11-19 08:18:14+00:00  1461609751830224898
# 4  2021-11-19 08:17:16+00:00  1461609507897937923
# 5  2021-11-19 08:15:41+00:00  1461609109078396932
# 6  2021-11-19 08:14:38+00:00  1461608846057619460
# 7  2021-11-19 08:13:48+00:00  1461608635390476290
# 8  2021-11-19 08:12:12+00:00  1461608233165070338
# 9  2021-11-19 08:09:49+00:00  1461607632129646599
# 10 2021-11-19 08:09:03+00:00  1461607438948446210
# 11 2021-11-19 08:04:54+00:00  1461606395426525187
# 12 2021-11-19 08:04:01+00:00  1461606174164402178
# 13 2021-11-19 08:02:56+00:00  1461605901610147846
# 14 2021-11-19 08:01:50+00:00  1461605622915416064
# 15 2021-11-18 19:09:55+00:00  1461411364245843976
# 16 2021-11-18 15:36:48+00:00  1461357732418580498
# 17 2021-11-18 15:30:20+00:00  1461356104546328584
# 18 2021-11-18 15:29:13+00:00  1461355822588436486
# 19 2021-11-18 15:22:31+00:00  1461354137191256070
# 20 2021-11-18 12:54:26+00:00  1461316869156188170
# 21 2021-11-18 12:53:54+00:00  1461316738058964992
# 22 2021-11-18 12:52:32+00:00  1461316390347055115
# 23 2021-11-18 12:49:25+00:00  1461315607849222144
# 24 2021-11-18 12:47:10+00:00  1461315040494112768
# 25 2021-11-18 12:44:56+00:00  1461314481594720257
# 26 2021-11-18 12:44:10+00:00  1461314287285280773
# 27 2021-11-18 12:40:14+00:00  1461313297383403527
# 28 2021-11-18 12:20:56+00:00  1461308440551297029
# 29 2021-11-18 12:19:58+00:00  1461308195708751877
# 30 2021-11-18 12:18:18+00:00  1461307777012412425
# 31 2021-11-18 08:37:21+00:00  1461252174848176130
# 32 2021-11-17 20:31:43+00:00  1461069559495077893
# 33 2021-11-17 20:30:24+00:00  1461069230271569925
# 34 2021-11-17 18:19:36+00:00  1461036311389818887
# 35 2021-11-17 18:18:38+00:00  1461036071895154698
# 36 2021-11-17 18:16:01+00:00  1461035410273062925
# 29  De kinderen waren tussen de 1 en 5 jaar oud. H...  SaskiaBelleman
# 30  In de rechtbank te Utrecht begint zo een inlei...  SaskiaBelleman
# 31  Het gaat om de verdachte in de zaak van de op ...  SaskiaBelleman
# 32                      Klopt https://t.co/8wNE0Yg5Qm  SaskiaBelleman
# 33                         Ja https://t.co/WwydyHGEg3  SaskiaBelleman
# 34                   U en ik. https://t.co/m1NfRlPY6r  SaskiaBelleman
# 35  Dat heb ik in hoger beroep niet meer terug hor...  SaskiaBelleman
# 36  Nee. Tenzij de rechtbank hem dwingt. https://t...  SaskiaBelleman
# 37               Liever niet. https://t.co/p2PLZCQm0K  SaskiaBelleman
# 38  En dat zet het hof er nog onverwacht snel een ...  SaskiaBelleman
# 39  Brassé vindt dat er geen sprake is van eenzelf...  SaskiaBelleman
# 40  Dat incident speelde in het vonnis van de rech...  SaskiaBelleman
# 41  Brassé zegt ook dat voor de verdediging helema...  SaskiaBelleman
# 42      Die is er altijd bij. https://t.co/VIbVj93TiC  SaskiaBelleman
# 43  In deze zaak zijn de schorsingen zo kort dat n...  SaskiaBelleman
# 44  Jawel, maar die is al op. https://t.co/W18oW2SCEy  SaskiaBelleman
# 45  Hij is alert en goed op dreef. https://t.co/zQ...  SaskiaBelleman
# 46             Ja, dat klopt. https://t.co/C2hzGesqc2  SaskiaBelleman
# 47  De frequentie van de tweets wordt even wat lag...  SaskiaBelleman
# 48  Het gaat over de vraag of tijdens de overlever...  SaskiaBelleman
# 49  Advocate Brassé neemt het woord over van Roeth...  SaskiaBelleman
# 50  U heeft duidelijk geen idee hoe het werkt. Wap...  SaskiaBelleman

# %%
def find_topic(df):
    topics = []
    for tweet in df['Text']: #Look through texts of tweets
        tweet = tweet.split()
        topic = np.nan # If there are no hastags, its a response tweet, so no topic
        for word in tweet:
            if word[0] == '#':
                topic = word[1::]
        topics.append(topic)
    
    topics = np.array(topics)
    df['Topic'] = topics
    return df[df['Topic']!='nan'].reset_index() #only return non-responsive tweets

# %%
tweets_df1 = find_topic(tweets_df1)

# %%
# Show all topics
def topics(df):
    unique = df['Topic'].unique()
    nr_unique = df['Topic'].nunique()
    return np.array(unique)

topics(tweets_df1) # Using # to find topic needs tweaking, remove punctuation to start
# Out:
# array(['Nicky', 'kinderopvang', 'Nicky.'], dtype=object)

# %%
# Find names
def names(df):
    names = []
    for tweet in df['Text']: #Look through texts of tweets
        tweet = tweet.split()
        for idx, word in enumerate(tweet):
            if len(word) == 2 and word.isupper():
                new_name = tweet[idx-1] + ' '+ tweet[idx]
                if new_name not in names:
                    names.append(new_name)

    names = np.array(names)
    return names

names(tweets_df1)
# Out:
# array(['Het OM', 'het OM', 'Jos B.'], dtype='<U6')

# %%
def preproces(lijst):
    # Remove punctuation, remove uppers (only to check, keep upper for return array)
    for text in array:
        print(i)
        for words in text:
            pass
    processed_array = lijst
    return processed_array

# %%
names(tweets_df1)
# Out:
# array(['Het OM', 'het OM', 'Jos B.'], dtype='<U6')
